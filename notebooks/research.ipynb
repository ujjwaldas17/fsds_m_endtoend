# %%
#ingest the data

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\fsds_m_endtoend\notebooks\data\gemstone.csv")

# %%
data.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
data.tail()
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 193568  193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39
# 193569  193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77
# 193570  193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75
# 193571  193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49
# 193572  193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71
#
#            z  price
# 193568  2.67   1130
# 193569  3.47   2874
# 193570  3.62   3036
# 193571  2.81    681
# 193572  3.48   2258

# %%
data.sample(5)
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 117761  117761   0.50  Very Good     H     SI1   63.1   56.0  5.04  5.09
# 86151    86151   1.02  Very Good     D     SI1   62.9   60.0  6.43  6.36
# 45276    45276   1.00  Very Good     D     SI2   61.8   56.0  6.31  6.37
# 46343    46343   0.31  Very Good     D     SI1   63.2   58.0  4.27  4.30
# 124556  124556   0.72      Ideal     G    VVS1   61.6   56.0  5.74  5.77
#
#            z  price
# 117761  3.19   1150
# 86151   4.03   6727
# 45276   3.91   3587
# 46343   2.71    732
# 124556  3.55   2749

# %%
data.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
data=data.drop(labels=["id"],axis=1)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (193573, 10)

# %%
categorical_colums=data.columns[data.dtypes=="object"]

# %%
numerical_colums=data.columns[data.dtypes!="object"]

# %%
data[categorical_colums].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
data[numerical_colums]
# Out:
#         carat  depth  table     x     y     z  price
# 0        1.52   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...    ...    ...   ...   ...   ...    ...
# 193568   0.31   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 7 columns]

# %%
data[numerical_colums].describe().T
# Out:
#           count         mean          std    min     25%      50%      75%  \
# carat  193573.0     0.790688     0.462688    0.2    0.40     0.70     1.03
# depth  193573.0    61.820574     1.081704   52.1   61.30    61.90    62.40
# table  193573.0    57.227675     1.918844   49.0   56.00    57.00    58.00
# x      193573.0     5.715312     1.109422    0.0    4.70     5.70     6.51
# y      193573.0     5.720094     1.102333    0.0    4.71     5.72     6.51
# z      193573.0     3.534246     0.688922    0.0    2.90     3.53     4.03
# price  193573.0  3969.155414  4034.374138  326.0  951.00  2401.00  5408.00
#
#             max
# carat      3.50
# depth     71.60
# table     79.00
# x          9.65
# y         10.01
# z         31.30
# price  18818.00

# %%
data[categorical_colums].value_counts()
# Out:
# cut    color  clarity
# Ideal  E      VS2        5490
#        G      VS2        5131
#               VS1        5107
#        E      SI1        4309
#        F      VS2        4235
#                          ...
#        J      I1            2
# Fair   D      I1            2
#        F      IF            1
#        D      VVS1          1
# Good   J      IF            1
# Name: count, Length: 276, dtype: int64

# %%
data[categorical_colums]["cut"].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
data[categorical_colums]["color"].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
data[categorical_colums]["clarity"].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64
